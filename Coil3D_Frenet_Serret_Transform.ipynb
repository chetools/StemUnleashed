# %% [markdown]
# <a href="https://colab.research.google.com/github/profteachkids/StemUnleashed/blob/main/Coil3D_Frenet_Serret_Transform.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import jax.numpy as jnp
import jax
from plotly.subplots import make_subplots

# %%
# def curve(t,R, mz):
#     return jnp.array([R*jnp.cos(t), R*jnp.sin(t), t*mz/(2*np.pi)])

def curve(t,R, mz):
    return jnp.array([R*jnp.cos(t), R*jnp.sin(t), jnp.exp(t/5)*mz/(2*np.pi)])

#Research on what is the Jacobian of a function.
#How does this differ from the gradient of a function?  
curve_jac=jax.jacobian(curve, 0)
curve_normal=jax.jacobian(curve_jac, 0)  #Frenet-Serret for normal
print(curve(np.pi/6.,1., 2*np.pi))
print(curve_jac(np.pi/6.,1., 2*np.pi))
print(curve_normal(np.pi/6.,1., 2*np.pi))
# Out:
# [0.8660254 0.5       1.1103994]
# [-0.5         0.8660254   0.22207987]
# [-0.8660254  -0.5         0.04441597]

# %%
def surf1(t,theta,r,R,mz):

    vl = curve(t,R,mz)
    v_jac = curve_jac(t,R,mz)

    #What are n1 and n2?
    #the choice of unit vector in z-direction leads to one normal always perpendicular to z
    #no difference for circle, but noticeable for ellipse cross-section
    n1=-jnp.cross(v_jac,jnp.array([0.,0.,1.]))
    n1=n1/jnp.linalg.norm(n1)
    n2=jnp.cross(n1,v_jac)
    n2=n2/jnp.linalg.norm(n2)

    #rotation matrix
    rot = jnp.array([[jnp.cos(theta), -jnp.sin(theta)],[jnp.sin(theta),jnp.cos(theta)]])

    vx = jnp.array([r,0])   #r along the x-coordinate
    vrot = jnp.matmul(rot, vx)  #rotate by theta
    vsurf = jnp.matmul(jnp.stack([n1,n2], axis=1),vrot)  #what is this???

    return vl+vsurf  #why add?

# %%
def surf2(t,theta,r,R,mz):

    vl = curve(t,R,mz)
    v_jac = curve_jac(t,R,mz)

    #Frenet-Serret
    #acceleration vector for n1
    #the magnitude of n1 is the acceleration with respect to t and important
    #if we were not just doing this to generate an elliptical cross-section
    n1=curve_normal(t,R,mz)
    n1=n1/jnp.linalg.norm(n1)
    n2=jnp.cross(n1,v_jac)
    n2=n2/jnp.linalg.norm(n2)

    #rotation matrix
    rot = jnp.array([[jnp.cos(theta), -jnp.sin(theta)],[jnp.sin(theta),jnp.cos(theta)]])

    vx = jnp.array([r,0])   #r along the x-coordinate
    vrot = jnp.matmul(rot, vx)  #rotate by theta
    vsurf = jnp.matmul(jnp.stack([n1,n2], axis=1),vrot)  #what is this???

    return vl+vsurf  #why add?

# %%
t=jnp.linspace(0,4*np.pi,120)
theta=jnp.linspace(0,2*np.pi,16)
R=1.
r=0.2
mz=0.8

surf1_v = jnp.vectorize(surf1, signature='(),(),(),(),()->(3)')
s1=surf1_v(t[:,None],theta[None,:],r, R,mz)

surf2_v = jnp.vectorize(surf2, signature='(),(),(),(),()->(3)')
s2=surf2_v(t[:,None],theta[None,:],r, R,mz)

jnp.sum(jnp.abs(s1-s2))
# Out:
# DeviceArray(12.441691, dtype=float32)

# %%
fig = make_subplots(rows=1,cols=1,specs=[[{'type': 'scene'}]])

for i in range(t.size):
    x,y,z = s1[i,:].T  #why tranpose?  take a look at unpacking for small matrices
    fig.add_scatter3d(x=x,y=y,z=z,mode='lines', line_color='white', row=1,col=1)

for i in range(theta.size):
    x,y,z = s1[:,i].T
    fig.add_scatter3d(x=x,y=y,z=z,mode='lines', line_color='white', row=1,col=1)

for i in range(t.size):
    x,y,z = s2[i,:].T
    fig.add_scatter3d(x=x,y=y,z=z,mode='lines', line_color='red', row=1,col=1)

for i in range(theta.size):
    x,y,z = s2[:,i].T
    fig.add_scatter3d(x=x,y=y,z=z,mode='lines', line_color='red', row=1,col=1)

fig.update_layout(width=800,template='plotly_dark',showlegend=False)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f1520161-2b0f-4c80-9fc0-e7a17129f05d" class="plotly-graph-div" style="height:525px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f1520161-2b0f-4c80-9fc0-e7a17129f05d")) {                    Plotly.newPlot(                        "f1520161-2b0f-4c80-9fc0-e7a17129f05d",                        [{"line":{"color":"white"},"mode":"lines","x":[0.800000011920929,0.8172909021377563,0.8661738634109497,0.9381966590881348,1.0209057331085205,1.100000023841858,1.1618034839630127,1.195629596710205,1.1956294775009155,1.1618033647537231,1.0999999046325684,1.020905613899231,0.9381964802742004,0.8661737442016602,0.8172908425331116,0.800000011920929],"y":[0.0,0.002070821588858962,0.0037835794501006603,0.004842121619731188,0.00506341690197587,0.004409201443195343,0.0029925943817943335,0.0010585407726466656,-0.0010585440322756767,-0.0029925969429314137,-0.004409203305840492,-0.0050634173676371574,-0.004842120222747326,-0.0037835766561329365,-0.002070818329229951,8.90192530800249e-10],"z":[0.1273239552974701,0.046002984046936035,-0.02125684916973114,-0.06282570958137512,-0.07151594758033752,-0.04582495987415314,0.009805053472518921,0.08575515449047089,0.16889287531375885,0.24484296143054962,0.3004729449748993,0.3261638879776001,0.3174735903739929,0.27590465545654297,0.2086448073387146,0.1273239254951477],"type":"scatter3d","scene":"scene"},{"line":{"color":"white"},"mode":"lines","x":[0.7955436110496521,0.8125153183937073,0.8609415888786316,0.9324491620063782,1.0146737098693848,1.093397855758667,1.1550095081329346,1.1888554096221924,1.189083218574524,1.155653715133667,1.0943470001220703,1.015763759613037,0.9334915280342102,0.8617560863494873,0.8129611015319824,0.7955436110496521],"y":[0.08432288467884064,0.08824862539768219,0.09514061361551285,0.10380716621875763,0.11274976283311844,0.12042213976383209,0.12549766898155212,0.12709876894950867,0.12494856119155884,0.11941885948181152,0.11146578937768936,0.10246451944112778,0.09397143870592117,0.08745508641004562,0.08404219895601273,0.08432288467884064],"z":[0.13004162907600403,0.0487217903137207,-0.01853710412979126,-0.06010536849498749,-0.06879550218582153,-0.0431048721075058,0.01252436637878418,0.08847340941429138,0.17160996794700623,0.24755899608135223,0.3031882047653198,0.3288787603378296,0.32018858194351196,0.27862024307250977,0.2113613486289978,0.13004159927368164],"type":"scatter3d","scene":"scene"},{"line":{"color":"white"},"mode":"lines","x":[0.7822241187095642,0.7986780405044556,0.8461002707481384,0.9162912368774414,0.9971141219139099,1.0745940208435059,1.1353340148925781,1.1688313484191895,1.1692942380905151,1.1366426944732666,1.0765222311019897,0.9993284344673157,0.9184087514877319,0.8477548956871033,0.7995836138725281,0.7822241187095642],"y":[0.16770634055137634,0.17344319820404053,0.18543757498264313,0.20161555707454681,0.21917980909347534,0.23509332537651062,0.24660450220108032,0.25172296166419983,0.24956364929676056,0.24049997329711914,0.22609907388687134,0.20885105431079865,0.19173820316791534,0.17771953344345093,0.16921895742416382,0.16770634055137634],"z":[0.13281729817390442,0.051498644053936005,-0.01575927436351776,-0.057326942682266235,-0.06601694226264954,-0.04032668471336365,0.015301749110221863,0.09124968945980072,0.17438504099845886,0.25033295154571533,0.30596137046813965,0.33165156841278076,0.3229615092277527,0.28139376640319824,0.21413582563400269,0.13281726837158203],"type":"scatter3d","scene":"scene"},{"line":{"color":"white"},"mode":"lines","x":[0.7601898908615112,0.7759330868721008,0.8218150734901428,0.8899024724960327,0.9684222936630249,1.0437978506088257,1.1029958724975586,1.1357805728912354,1.1364831924438477,1.1049821376800537,1.0467244386672974,0.9717831611633301,0.8931164145469666,0.8243264555931091,0.7773076295852 ...

# %%
#what is the purpose of (0,1)
surf_jac=jax.jacobian(surf,(0,1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-223-0e21fd808a9e> in <module>()
#       1 #what is the purpose of (0,1)
# ----> 2 surf_jac=jax.jacobian(surf,(0,1))
#
# NameError: name 'surf' is not defined

# %%
#examine different t, theta (multiples of pi/2) values and for convenient r, R and also mz=0 
surf(0.,0.,r, R, 0.8)
# Out:
# DeviceArray([1.2, 0. , 0. ], dtype=float32)

# %%
#In the Jacobian, why does 1.2 being equal to R+r and 0.1975 being close to r=0.2 make sense?
surf_jac(0.,0.,r,R,1)
# Out:
# (DeviceArray([0.        , 1.2       , 0.15915494], dtype=float32, weak_type=True),
#  DeviceArray([ 0.        , -0.03143534,  0.1975141 ], dtype=float32, weak_type=True))

# %%
nt=120
ntheta=64
t=jnp.linspace(0,4*np.pi,nt,endpoint=False)
theta=jnp.linspace(0,2*np.pi,ntheta,endpoint=False)

dt=4*np.pi/nt
dtheta=2*np.pi/ntheta

def surf_jacdet(t,theta,r):

    #why name these dxyz_dt and dxyz_dtheta?
    dxyz_dt, dxyz_dtheta = surf_jac(t,theta,r,R,mz)

    #why do we multiply by dt and dtheta?
    #recall the geometric meaning of the cross product
    return jnp.linalg.norm(jnp.cross(dxyz_dt*dt, dxyz_dtheta*dtheta))

surf_jacdet_vec=jnp.vectorize(surf_jacdet,signature='(),(),()->()')

jnp.sum(surf_jacdet_vec(t[:,None],theta[None,:],r))
# Out:
# DeviceArray(15.918863, dtype=float32)

# %%
#arc length of curve, what approximation are we making here for the area?
curve_jac_vec=jnp.vectorize(curve_jac,signature='(),(),()->(3)')

#why do we take the sqrt and sum of squares?
arclength=jnp.sum(jnp.sqrt(jnp.sum(curve_jac_vec(t,R,mz)**2,axis=1)))*dt
arclength*2*np.pi*r
# Out:
# DeviceArray(15.918854, dtype=float32)
