# %% [markdown]
# <a href="https://colab.research.google.com/github/profteachkids/StemUnleashed/blob/main/21June_GeneticAlgorithm_TSP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import numba
from plotly.subplots import make_subplots
np.set_printoptions(formatter={'float':lambda x: f'{x:0.2f}'})

# %%
rng=np.random.RandomState(123)

# %%
N=100
coords=rng.uniform(0,10, size=(N,2))

# %%
dist=np.sqrt(np.sum((coords[:,None,:]-coords[None,:,:])**2,axis=2))

# %%
def calcdist(seq):
    return np.sum(dist[seq[1:,:],seq[:-1,:]]) + dist[seq[0,:],seq[-1,:]]

# %%
def topn(seq,n):
    dists=calcdist(seq)
    topn_idx=np.argsort(dists)[:n]
    return seq[:,topn_idx], dists[topn_idx]

# %%
popsize = 512
seq=np.zeros((N,popsize), dtype=int)

for popidx in range(popsize):

    remain = list(range(N))

    cur = rng.randint(N)
    seq[0,popidx]=cur
    remain.remove(cur)
    for i in range(1,N-1):
        best2= np.argsort(dist[cur,remain])[:2]
        best=remain[best2[rng.choice([0,1],p=(0.95,0.05))]  ]
        seq[i,popidx]=best
        cur=best
        remain.remove(best)
    seq[-1,popidx]=remain[0]

# %%
top20, dists20 = topn(seq,20)

# %%
def plotter(seq_plot, dists, nr, nc):
    fig=make_subplots(rows = nr, cols=nc)
    seq = np.r_[seq_plot, np.atleast_2d(seq_plot[0,:])]
    for i in range(seq.shape[1]):
        fig.add_scatter(x=coords[seq[:,i],0], y=coords[seq[:,i],1], row=i//nc+1, col=i%nc +1)
    fig.update_layout(template='plotly_dark', showlegend=False)
    fig.show()

# %%
plotter(top20, dists20, nr=4, nc=5)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="2ecdac51-2418-419c-89e3-1c647f0b4dfc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2ecdac51-2418-419c-89e3-1c647f0b4dfc")) {                    Plotly.newPlot(                        "2ecdac51-2418-419c-89e3-1c647f0b4dfc",                        [{"x":[0.6973491719944513,1.4613703730645033,2.6535752394084735,3.716358264548798,4.15896556394369,3.9147935414994506,4.91510639441527,5.018973605524253,4.930027325538386,7.654751241649898,9.46620896646696,8.788935471020283,8.689078523201246,8.889897385795042,8.380811280577888,8.066037608804468,8.125700841807188,7.51173755298535,7.198792779251816,6.83989196407776,7.203556424148817,7.152568069704116,7.1249242611788475,6.552131835038438,5.8668129550657255,5.806062561254047,5.419694081167295,5.51470612420254,5.218407929504592,5.21010875426266,5.058042464984135,5.18660891582733,5.489404842066251,6.297276340470472,6.535232615737342,6.308181956673577,6.2522426593044935,6.043401637345647,5.751352859608247,6.480711575507917,7.445352162812928,7.446300631853548,7.846048175419012,7.379513733805956,6.993796479400817,8.372507641877522,8.227363952261332,8.891986053886619,9.205011882084253,9.675113303374257,9.11388996168034,8.923394849437638,8.804166642755007,8.973049386665743,9.839275636184652,9.742319764928023,9.538969332498166,9.757308440402978,9.656976427334243,8.920754898569653,7.423863501150356,6.79530288365254,6.37750959640117,5.538271069939837,5.356261761284698,5.638565420585369,5.049628561587899,4.462149309981607,4.914751692674589,4.2945962357793395,4.961962866529808,5.9655266410297365,4.314860529331441,3.8972964412935953,3.725193910445782,3.6248491127415305,3.052291082282937,2.967312979105896,3.0051670890285287,2.8236280632272006,1.8249983206819154,1.6811676721189894,1.0399177624038125,0.3920363397078952,0.8043277269406246,0.5812513570014288,1.1702945148503585,0.7242446813412262,0.9432077446647824,2.7719490987354867,0.5125490950100942,0.7722272796212248,1.3262045563523195,1.2138278210674502,1.3630924621656737,2.4639504625086026,3.1354249118955977,3.2350826853736714,0.29456993006431453,0.8438843423226561,0.6973491719944513],"y":[9.979801769556776,8.389132737851657,7.6243827396395005,7.740198028119185,7.713079290263638,7.021043682229098,8.2014203851923,8.356653023141103,9.793603423915588,9.824312356540496,9.132312556125656,7.922077827975055,7.557219582608209,7.2932239024613565,6.516425610789554,6.029501879313505,5.282055260711115,5.113173914981939,5.105923958201211,5.298252112514997,5.524804086648333,6.2828149069445836,6.836154748906184,7.476597889282088,7.227019421308093,6.289343337329955,5.800523263528008,5.623206479316788,5.794972390827038,4.793341706829564,4.449849590689041,4.116584942412665,4.3610733965897905,4.010122763696481,3.549030016359681,3.3070654780335005,3.15143022702756,3.0511364646643235,3.2256774763771823,2.9769380118428215,3.3431073346872697,4.011859250238295,4.3458618503202135,4.732268449615331,4.595969239604745,3.507623102483617,3.5299237041555145,3.3939747140229803,3.0396409854169235,2.8141752377861584,4.004121106475374,4.785709545471901,5.405378182020265,5.82015327867078,5.756658183968051,6.752333557075181,4.770002274003807,4.700032317649515,0.9050987710635694,0.3454501876496263,0.6753656581938305,0.5381499589254157,0.6815258298855154,1.172068378695058,1.091564818399735,1.3257374045597303,0.827195476126702,0.40934136567943424,0.009045597035614028,1.2910116084806977,1.7234262762093788,2.481698873890019,3.605650380574473,4.022648054526732,3.3997017130689464,3.182136407131294,3.441119252755281,3.9356374015060513,4.093904125930584,4.185398766927413,4.20538764185718,4.745946836621748,4.65927153140389,5.134893499629646,5.66346735394167,5.880174189514392,6.284705798834168,6.794360219 ...

# %%
@numba.njit
def isin(val, arr):
    for item in arr:
        if val==item:
            return True
    return False

@numba.njit
def swap(p1,p2,c1,c2):
    o=np.zeros_like(p1)
    N=p1.size
    swap=np.concatenate((p2[c2:],p2[:c2]))
    retain=p1[c1:c2]

    filtered=[]
    for i in swap:
        if not(isin(i,retain)):
            filtered.append(i)
    o[c1:c2]=p1[c1:c2]
    o[c2:]=filtered[:(N-c2)]
    o[:c1]=filtered[(N-c2):]
    return o

@numba.njit
def mate2p(p1,p2):
    N=p1.size
    c1=np.random.randint(N//4,N//2)
    c2=np.random.randint(N//2, 3*N//4)
    
    o1=swap(p1,p2,c1,c2)
    o2=swap(p2,p1,c1,c2)
    return o1,o2

@numba.njit
def mate(s):
    seq=s[:,np.random.permutation(np.arange(s.shape[1]))]
    offspring=np.zeros_like(seq)
    for i,(p1,p2) in enumerate(zip(seq[:,::2].T, seq[:,1::2].T)):
        offspring[:,2*i],offspring[:,2*i+1]=mate2p(p1,p2)
    return offspring

# %%
# %%timeit
mate(seq)
# Out:
# 100 loops, best of 5: 3.3 ms per loop

# %%
144
36
5.53
3.36
3.3
# Out:
# array([[8, 8, 4, 5, 1, 9, 3, 3, 7, 8, 1, 2, 8, 5, 5, 1, 7, 9, 7, 5],
#        [6, 6, 9, 7, 5, 4, 9, 2, 5, 6, 5, 0, 6, 7, 7, 5, 5, 4, 5, 7],
#        [4, 4, 2, 9, 7, 0, 4, 0, 1, 4, 7, 4, 4, 9, 9, 7, 1, 0, 1, 9],
#        [9, 9, 0, 4, 9, 2, 0, 4, 4, 9, 9, 9, 9, 4, 4, 9, 4, 2, 4, 4],
#        [2, 2, 6, 0, 4, 3, 2, 9, 9, 2, 4, 7, 2, 0, 0, 4, 9, 3, 9, 0],
#        [0, 0, 8, 2, 0, 7, 7, 7, 2, 0, 0, 5, 3, 2, 2, 0, 2, 7, 2, 2],
#        [3, 3, 1, 3, 2, 5, 5, 5, 0, 3, 2, 1, 0, 3, 3, 2, 0, 5, 0, 3],
#        [7, 7, 5, 1, 3, 1, 1, 1, 6, 7, 3, 8, 1, 1, 1, 3, 6, 1, 6, 1],
#        [5, 5, 7, 8, 6, 8, 8, 8, 8, 5, 6, 6, 5, 8, 8, 6, 8, 8, 8, 8],
#        [1, 1, 3, 6, 8, 6, 6, 6, 3, 1, 8, 3, 7, 6, 6, 8, 3, 6, 3, 6]])

# %%
for i, (vehicle,fruit) in enumerate(zip(a,b)):
    print(f'Step {i}: I ate a {fruit} in a {vehicle}')
# Out:
# Step 0: I ate a apple in a car
# Step 1: I ate a orange in a boat
# Step 2: I ate a banana in a jet

# %%
for i, fruit in enumerate(b):
    print(i, fruit)
# Out:
# 0 apple
# 1 orange
# 2 banana

# %%
p1=np.array([3,4,8,2,7,1,6,5])
p2=np.array([4,2,5,1,6,8,3,7])

# %%
arr=np.arange(int(1e7))

# %%
# %%timeit
isin(int(9.99e6),arr)
# Out:
# 100 loops, best of 5: 9.58 ms per loop
